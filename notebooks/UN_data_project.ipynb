# %% [markdown]
# ## PACKAGES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Using the pandas read_csv() method, read the GDP dataset into your notebook as a DataFrame called gdp_df. Take a look at the first few and last few rows to familiarize yourself with what is contained in this dataset.

# %%
gdp_df=pd.read_csv('../data/gdp_percapita.csv')

# %% [markdown]
# ##4 Using the pandas read_csv() method, read the GDP dataset into your notebook as a DataFrame called gdp_df. Take a look at the first few and last few rows to familiarize yourself with what is contained in this dataset.

# %%
gdp_df.head()
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2021  1517.016266              NaN
# 1     Afghanistan  2020  1968.341002              NaN
# 2     Afghanistan  2019  2079.921861              NaN
# 3     Afghanistan  2018  2060.698973              NaN
# 4     Afghanistan  2017  2096.093111              NaN

# %%
gdp_df.tail()
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 7657        Zimbabwe  1994  2670.106615              NaN
# 7658        Zimbabwe  1993  2458.783255              NaN
# 7659        Zimbabwe  1992  2468.278257              NaN
# 7660        Zimbabwe  1991  2781.787843              NaN
# 7661        Zimbabwe  1990  2704.757299              NaN

# %% [markdown]
# ##5 How many rows and columns are in gdp_df? What are the data types of each column?

# %%
gdp_df.shape
# Out:
# (7662, 4)

# %%
gdp_df.shape[0]
# Out:
# 7662

# %%
gdp_df.shape[1]
# Out:
# 4

# %%
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7662 entries, 0 to 7661
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country or Area  7662 non-null   object
#  1   Year             7662 non-null   int64
#  2   Value            7662 non-null   float64
#  3   Value Footnotes  0 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 239.6+ KB

# %%
gdp_df.dtypes
# Out:
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object

# %%
print(gdp_df.shape)
print(gdp_df.info())
# Out:
# (7662, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7662 entries, 0 to 7661
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country or Area  7662 non-null   object
#  1   Year             7662 non-null   int64
#  2   Value            7662 non-null   float64
#  3   Value Footnotes  0 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 239.6+ KB
# None

# %% [markdown]
# ##6 Drop the Value Footnotes column and rename the remaining three to 'Country', 'Year', and 'GDP_Per_Capita'.

# %%
gdp_df.drop(columns=['Value Footnotes'])
# Out:
#      Country or Area  Year        Value
# 0        Afghanistan  2021  1517.016266
# 1        Afghanistan  2020  1968.341002
# 2        Afghanistan  2019  2079.921861
# 3        Afghanistan  2018  2060.698973
# 4        Afghanistan  2017  2096.093111
# ...              ...   ...          ...
# 7657        Zimbabwe  1994  2670.106615
# 7658        Zimbabwe  1993  2458.783255
# 7659        Zimbabwe  1992  2468.278257
# 7660        Zimbabwe  1991  2781.787843
# 7661        Zimbabwe  1990  2704.757299
#
# [7662 rows x 3 columns]

# %%
gdp_dff = gdp_df.drop(columns=['Value Footnotes'])

# %%
print(gdp_dff)
# Out:
#      Country or Area  Year        Value
# 0        Afghanistan  2021  1517.016266
# 1        Afghanistan  2020  1968.341002
# 2        Afghanistan  2019  2079.921861
# 3        Afghanistan  2018  2060.698973
# 4        Afghanistan  2017  2096.093111
# ...              ...   ...          ...
# 7657        Zimbabwe  1994  2670.106615
# 7658        Zimbabwe  1993  2458.783255
# 7659        Zimbabwe  1992  2468.278257
# 7660        Zimbabwe  1991  2781.787843
# 7661        Zimbabwe  1990  2704.757299
#
# [7662 rows x 3 columns]

# %% [markdown]
# ## gdp_df.columns = ['Country', 'Year', 'GDP_Per_Capita]----Also works

# %%
gdp_dff.rename(columns={'Country or Area' : 'Country', 'Value': 'GDP_Per_Capita'})
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2021     1517.016266
# 1     Afghanistan  2020     1968.341002
# 2     Afghanistan  2019     2079.921861
# 3     Afghanistan  2018     2060.698973
# 4     Afghanistan  2017     2096.093111
# ...           ...   ...             ...
# 7657     Zimbabwe  1994     2670.106615
# 7658     Zimbabwe  1993     2458.783255
# 7659     Zimbabwe  1992     2468.278257
# 7660     Zimbabwe  1991     2781.787843
# 7661     Zimbabwe  1990     2704.757299
#
# [7662 rows x 3 columns]

# %%
gdp_dff = gdp_df.rename(columns={'Country or Area' : 'Country', 
                                'Value': 'GDP_Per_Capita'})

# %%
print(gdp_dff)
# Out:
#           Country  Year  GDP_Per_Capita  Value Footnotes
# 0     Afghanistan  2021     1517.016266              NaN
# 1     Afghanistan  2020     1968.341002              NaN
# 2     Afghanistan  2019     2079.921861              NaN
# 3     Afghanistan  2018     2060.698973              NaN
# 4     Afghanistan  2017     2096.093111              NaN
# ...           ...   ...             ...              ...
# 7657     Zimbabwe  1994     2670.106615              NaN
# 7658     Zimbabwe  1993     2458.783255              NaN
# 7659     Zimbabwe  1992     2468.278257              NaN
# 7660     Zimbabwe  1991     2781.787843              NaN
# 7661     Zimbabwe  1990     2704.757299              NaN
#
# [7662 rows x 4 columns]

# %% [markdown]
# ##7 How many countries have data for all years? Which countries are missing many years of data? Look at the number of observations per year. What do you notice?---

# %% [markdown]
# ## 202. 40 missing, Some countries data started getting inputed at a later date

# %%
gdp_dff['Year'].nunique()
# Out:
# 33

# %%
gdp_dff['Year'].unique()
# Out:
# array([2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011,
#        2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2022, 2001,
#        2000, 1999, 1998, 1997, 1996, 1995, 1994, 1993, 1992, 1991, 1990],
#       dtype=int64)

# %%
gdp_dff['Year'].sort_values().unique().tolist()
# Out:
# [1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021,
#  2022]

# %% [markdown]
# value_counts() counts the occurence of unique values in a particular column or series

# %%
gdp_dff['Country'].value_counts()
# Out:
# Country
# Least developed countries: UN classification    33
# Middle East & North Africa                      33
# Middle East & North Africa (IDA & IBRD)         33
# Middle income                                   33
# Mongolia                                        33
#                                                 ..
# Kosovo                                          15
# Sint Maarten (Dutch part)                       14
# Turks and Caicos Islands                        12
# Somalia                                         10
# Djibouti                                        10
# Name: count, Length: 242, dtype: int64

# %%
count_df = gdp_dff['Country'].value_counts().reset_index()

# %%
count_df[count_df['count']==33]['count'].count()
# Out:
# 202

# %%
count_df[count_df['count']<33]['count'].count()
# Out:
# 40

# %%
gdp_dff['Country'].value_counts().reset_index().reset_index()
# Out:
#      index                                       Country  count
# 0        0  Least developed countries: UN classification     33
# 1        1                    Middle East & North Africa     33
# 2        2       Middle East & North Africa (IDA & IBRD)     33
# 3        3                                 Middle income     33
# 4        4                                      Mongolia     33
# ..     ...                                           ...    ...
# 237    237                                        Kosovo     15
# 238    238                     Sint Maarten (Dutch part)     14
# 239    239                      Turks and Caicos Islands     12
# 240    240                                       Somalia     10
# 241    241                                      Djibouti     10
#
# [242 rows x 3 columns]

# %%
gdp_dff[gdp_dff['Country']=='Pakistan'].sort_values(by='Year')
# Out:
#        Country  Year  GDP_Per_Capita  Value Footnotes
# 5391  Pakistan  1990     3061.533388              NaN
# 5390  Pakistan  1991     3114.242099              NaN
# 5389  Pakistan  1992     3267.290688              NaN
# 5388  Pakistan  1993     3240.735549              NaN
# 5387  Pakistan  1994     3265.651279              NaN
# 5386  Pakistan  1995     3328.001920              NaN
# 5385  Pakistan  1996     3384.609986              NaN
# 5384  Pakistan  1997     3319.869472              NaN
# 5383  Pakistan  1998     3307.510088              NaN
# 5382  Pakistan  1999     3331.953041              NaN
# 5381  Pakistan  2000     3368.681897              NaN
# 5380  Pakistan  2001     3382.204838              NaN
# 5379  Pakistan  2002     3381.140813              NaN
# 5378  Pakistan  2003     3499.018602              NaN
# 5377  Pakistan  2004     3679.907116              NaN
# 5376  Pakistan  2005     3836.090287              NaN
# ...

# %%
gdp_dff.rename(columns={'Country or Area' : 'Country', 
                                'Value': 'GDP_Per_Capita'})
# Out:
#           Country  Year  GDP_Per_Capita  Value Footnotes
# 0     Afghanistan  2021     1517.016266              NaN
# 1     Afghanistan  2020     1968.341002              NaN
# 2     Afghanistan  2019     2079.921861              NaN
# 3     Afghanistan  2018     2060.698973              NaN
# 4     Afghanistan  2017     2096.093111              NaN
# ...           ...   ...             ...              ...
# 7657     Zimbabwe  1994     2670.106615              NaN
# 7658     Zimbabwe  1993     2458.783255              NaN
# 7659     Zimbabwe  1992     2468.278257              NaN
# 7660     Zimbabwe  1991     2781.787843              NaN
# 7661     Zimbabwe  1990     2704.757299              NaN
#
# [7662 rows x 4 columns]

# %%
gdp_dff[gdp_dff['Country']=='Kosovo']
# Out:
#      Country  Year  GDP_Per_Capita  Value Footnotes
# 3602  Kosovo  2022    12469.446468              NaN
# 3603  Kosovo  2021    11884.179915              NaN
# 3604  Kosovo  2020    10706.513976              NaN
# 3605  Kosovo  2019    11318.462250              NaN
# 3606  Kosovo  2018    10755.167539              NaN
# 3607  Kosovo  2017    10436.168846              NaN
# 3608  Kosovo  2016    10031.044170              NaN
# 3609  Kosovo  2015     9445.105476              NaN
# 3610  Kosovo  2014     8796.629620              NaN
# 3611  Kosovo  2013     8486.565497              NaN
# 3612  Kosovo  2012     8105.374932              NaN
# 3613  Kosovo  2011     8040.593814              NaN
# 3614  Kosovo  2010     7627.891430              NaN
# 3615  Kosovo  2009     7327.439197              NaN
# 3616  Kosovo  2008     7032.452297              NaN

# %%
print(gdp_dff.min())
# Out:
# Country            Afghanistan
# Year                      1990
# GDP_Per_Capita      436.376416
# Value Footnotes            NaN
# dtype: object

# %%
print(gdp_dff.max())
# Out:
# Country                 Zimbabwe
# Year                        2022
# GDP_Per_Capita     157602.482546
# Value Footnotes              NaN
# dtype: object

# %%
print(gdp_dff)
# Out:
#           Country  Year  GDP_Per_Capita  Value Footnotes
# 0     Afghanistan  2021     1517.016266              NaN
# 1     Afghanistan  2020     1968.341002              NaN
# 2     Afghanistan  2019     2079.921861              NaN
# 3     Afghanistan  2018     2060.698973              NaN
# 4     Afghanistan  2017     2096.093111              NaN
# ...           ...   ...             ...              ...
# 7657     Zimbabwe  1994     2670.106615              NaN
# 7658     Zimbabwe  1993     2458.783255              NaN
# 7659     Zimbabwe  1992     2468.278257              NaN
# 7660     Zimbabwe  1991     2781.787843              NaN
# 7661     Zimbabwe  1990     2704.757299              NaN
#
# [7662 rows x 4 columns]

# %%
countries = gdp_dff.groupby('Country')['Year'].count().sort_values().reset_index()

# %%
countries
# Out:
#                        Country  Year
# 0                     Djibouti    10
# 1                      Somalia    10
# 2     Turks and Caicos Islands    12
# 3    Sint Maarten (Dutch part)    14
# 4                       Kosovo    15
# ..                         ...   ...
# 237                    Jamaica    33
# 238                      Japan    33
# 239                     Jordan    33
# 240                  IDA total    33
# 241                   Zimbabwe    33
#
# [242 rows x 2 columns]

# %%
countries[countries['Year']<33]
# Out:
#                       Country  Year
# 0                    Djibouti    10
# 1                     Somalia    10
# 2    Turks and Caicos Islands    12
# 3   Sint Maarten (Dutch part)    14
# 4                      Kosovo    15
# 5              Cayman Islands    16
# 6                       Nauru    19
# 7                 Afghanistan    20
# 8                    Cura̤ao    22
# 9                       Palau    22
# 10    Ṣo Tom̩ and Principe    22
# 11                      Qatar    23
# 12         Other small states    23
# 13                Timor-Leste    23
# 14                    Liberia    23
# 15                      Libya    24
# 16                 San Marino    25
# 17               Small states    26
# 18                 Montenegro    26
# 19                   Maldives    28
# 20                    Moldova    28
# 21                     Israel    28
# 22                    Iceland    28
# 23                    Estonia    28
# 24                    Croatia    28
# ...

# %%
gdp_years = gdp_dff.groupby("Country")
gdp_last = gdp_years.last()
gdp_min = gdp_last.sort_values(by="Year",ascending=False)
# All countries' first appearance in the dataset
gdp_min[gdp_min["Year"]>1990]
# All countries' whose first appearance was after 1990
# Out:
#                            Year  GDP_Per_Capita  Value Footnotes
# Country
# Somalia                    2013      889.166677              NaN
# Djibouti                   2013     3664.268036              NaN
# Turks and Caicos Islands   2011    25731.283253              NaN
# Sint Maarten (Dutch part)  2009    41969.404381              NaN
# Kosovo                     2008     7032.452297              NaN
# Cayman Islands             2006    84778.384261              NaN
# Nauru                      2004     5342.330551              NaN
# Afghanistan                2002     1280.463171              NaN
# Ṣo Tom̩ and Principe    2001     2558.983512              NaN
# Palau                      2000    13301.254248              NaN
# Cura̤ao                   2000    28613.900065              NaN
# Other small states         2000    13522.865601              NaN
# Qatar                      2000    79400.433413              NaN
# ...

# %% [markdown]
# ##In this question, you're going to create some plots to show the distribution of GDP per capita for the year 2020. Go to the Python Graph Gallery (https://www.python-graph-gallery.com/) and look at the different types of plots under the Distribution section. Create a histogram, a density plot, a boxplot, and a violin plot. What do you notice when you look at these plots? How do the plots compare and what information can you get out of one type that you can't necessarily get out of the others?

# %% [markdown]
# ###Answer: The histogram, a density plot, and violin plot all show the same data in an undefined way. The boxplot is most helpful because it shows: median, quartiles and outliers but also hides the dataset individual data points.

# %%
gdp_dff[gdp_dff["Year"]==2020]
# Out:
#                           Country  Year  GDP_Per_Capita  Value Footnotes
# 1                     Afghanistan  2020     1968.341002              NaN
# 22    Africa Eastern and Southern  2020     3455.023119              NaN
# 55     Africa Western and Central  2020     3957.933804              NaN
# 88                        Albania  2020    13278.369769              NaN
# 121                       Algeria  2020    10844.770764              NaN
# ...                           ...   ...             ...              ...
# 7503                     Viet Nam  2020    10450.622382              NaN
# 7536           West Bank and Gaza  2020     5402.538773              NaN
# 7565                        World  2020    16204.169107              NaN
# 7598                       Zambia  2020     3183.650773              NaN
# 7631                     Zimbabwe  2020     1990.319419              NaN
#
# [242 rows x 4 columns]

# %%
gdp_2020 = gdp_dff[gdp_dff["Year"]==2020]

# %%
gdp_2020
# Out:
#                           Country  Year  GDP_Per_Capita  Value Footnotes
# 1                     Afghanistan  2020     1968.341002              NaN
# 22    Africa Eastern and Southern  2020     3455.023119              NaN
# 55     Africa Western and Central  2020     3957.933804              NaN
# 88                        Albania  2020    13278.369769              NaN
# 121                       Algeria  2020    10844.770764              NaN
# ...                           ...   ...             ...              ...
# 7503                     Viet Nam  2020    10450.622382              NaN
# 7536           West Bank and Gaza  2020     5402.538773              NaN
# 7565                        World  2020    16204.169107              NaN
# 7598                       Zambia  2020     3183.650773              NaN
# 7631                     Zimbabwe  2020     1990.319419              NaN
#
# [242 rows x 4 columns]

# %%
sns.violinplot(y=gdp_2020["GDP_Per_Capita"])
plt.ylabel('GDP_Per_Capita')
plt.title('Violin Plot')
# Out:
# Text(0.5, 1.0, 'Violin Plot')

# %%
sns.displot( data=gdp_2020["GDP_Per_Capita"], kde=True )
plt.ylabel('Count')
plt.title('Displot')
# Out:
# Text(0.5, 1.0, 'Displot')

# %%
sns.kdeplot(gdp_2020['GDP_Per_Capita'])
plt.ylabel('Density')
plt.title('KDE Plot')
# Out:
# Text(0.5, 1.0, 'KDE Plot')

# %%
sns.boxplot( y=gdp_2020["GDP_Per_Capita"] )
plt.ylabel('GDP_Per_Capita')
plt.title('BoxPlot')
# Out:
# Text(0.5, 1.0, 'BoxPlot')

# %% [markdown]
# 9###What was the median GDP per capita value in 2020?
#
# ###Answer 13357.997573370474

# %%
gdp_2020["GDP_Per_Capita"].median()
# Out:
# 13357.997573370474

# %% [markdown]
# 10####For this question, you're going to create some visualizations to compare GDP per capita values for the years 1990, 2000, 2010, and 2020. Start by subsetting your data to just these 4 years into a new DataFrame named gdp_decades. Using this, create the following 4 plots:
#
# A boxplot
#
# A barplot (check out the Barplot with Seaborn section: https://www.python-graph-gallery.com/barplot/#Seaborn)
#
# A scatterplot
#
# A scatterplot with a trend line overlaid (see this regplot example: https://www.python-graph-gallery.com/42-custom-linear-regression-fit-seaborn)
#
# Comment on what you observe has happened to GDP values over time and the relative strengths and weaknesses of each type of plot.

# %%
my_years=[1990, 2000, 2010, 2020]

# %%
my_years
# Out:
# [1990, 2000, 2010, 2020]

# %%
gdp_dff[gdp_dff['Year'].isin(my_years)]
# Out:
#                           Country  Year  GDP_Per_Capita  Value Footnotes
# 1                     Afghanistan  2020     1968.341002              NaN
# 11                    Afghanistan  2010     2026.163818              NaN
# 22    Africa Eastern and Southern  2020     3455.023119              NaN
# 32    Africa Eastern and Southern  2010     3513.315920              NaN
# 42    Africa Eastern and Southern  2000     2897.140841              NaN
# ...                           ...   ...             ...              ...
# 7628                       Zambia  1990     2290.039226              NaN
# 7631                     Zimbabwe  2020     1990.319419              NaN
# 7641                     Zimbabwe  2010     1799.540233              NaN
# 7651                     Zimbabwe  2000     2750.601236              NaN
# 7661                     Zimbabwe  1990     2704.757299              NaN
#
# [921 rows x 4 columns]

# %%
gdp_dff['Year'].isin([1990, 2000, 2010, 2020])
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 7657    False
# 7658    False
# 7659    False
# 7660    False
# 7661     True
# Name: Year, Length: 7662, dtype: bool

# %%
gdp_decades=gdp_dff[gdp_dff['Year'].isin([1990, 2000, 2010, 2020])]

# %%
sns.boxplot(data= gdp_decades,
            x='Year',
            y='GDP_Per_Capita')
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %%
sns.barplot(data= gdp_decades,
            x='Year',
            y='GDP_Per_Capita')
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %%
sns.scatterplot(data= gdp_decades,
            x='Year',
            y='GDP_Per_Capita')
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %%
sns.regplot(data= gdp_decades,
            x='Year',
            y='GDP_Per_Capita')
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %% [markdown]
# 11##Which country was the first to have a GDP per capita greater than $100,000?
#
# Answer is United Arab Emirates	1990	105893.626059

# %%
sns.__version__
# Out:
# '0.13.2'

# %%
gdp_dff[gdp_dff['GDP_Per_Capita']>100000].sort_values('Year')
# Out:
#                    Country  Year  GDP_Per_Capita  Value Footnotes
# 7302  United Arab Emirates  1990   105893.626059              NaN
# 7301  United Arab Emirates  1991   101048.696239              NaN
# 7295  United Arab Emirates  1997   100956.706467              NaN
# 4167            Luxembourg  2001   101143.147977              NaN
# 4166            Luxembourg  2002   103317.331098              NaN
# 4165            Luxembourg  2003   104743.000088              NaN
# 4164            Luxembourg  2004   107634.837198              NaN
# 4163            Luxembourg  2005   108632.360016              NaN
# 4162            Luxembourg  2006   113346.035782              NaN
# 4161            Luxembourg  2007   120647.822959              NaN
# 4160            Luxembourg  2008   118154.667184              NaN
# 4159            Luxembourg  2009   112230.081410              NaN
# 5756                 Qatar  2010   103902.519310              NaN
# ...

# %% [markdown]
# 12##Which country had the highest GDP per capita in 2020? Create a plot showing how this country's GDP per capita has changed over the timespan of the dataset.

# %%
gdp_dff[gdp_dff['GDP_Per_Capita']>100000].sort_values('Year')
# Out:
#                    Country  Year  GDP_Per_Capita  Value Footnotes
# 7302  United Arab Emirates  1990   105893.626059              NaN
# 7301  United Arab Emirates  1991   101048.696239              NaN
# 7295  United Arab Emirates  1997   100956.706467              NaN
# 4167            Luxembourg  2001   101143.147977              NaN
# 4166            Luxembourg  2002   103317.331098              NaN
# 4165            Luxembourg  2003   104743.000088              NaN
# 4164            Luxembourg  2004   107634.837198              NaN
# 4163            Luxembourg  2005   108632.360016              NaN
# 4162            Luxembourg  2006   113346.035782              NaN
# 4161            Luxembourg  2007   120647.822959              NaN
# 4160            Luxembourg  2008   118154.667184              NaN
# 4159            Luxembourg  2009   112230.081410              NaN
# 5756                 Qatar  2010   103902.519310              NaN
# ...

# %%
gdp_dff[gdp_dff['Year']==2020].nlargest(1, 'GDP_Per_Capita')
# Out:
#          Country  Year  GDP_Per_Capita  Value Footnotes
# 4148  Luxembourg  2020   111751.314751              NaN

# %%
gdp_dff[gdp_dff['Year']==2020]['GDP_Per_Capita'].max()
# Out:
# 111751.3147513618

# %%
gdp_dff[(gdp_dff['Year']==2020) & (gdp_dff['GDP_Per_Capita']==111751.3147513618)]
# Out:
#          Country  Year  GDP_Per_Capita  Value Footnotes
# 4148  Luxembourg  2020   111751.314751              NaN

# %%
top_country = gdp_dff[gdp_dff['Country']=='Luxembourg']

# %%
top_country
# Out:
#          Country  Year  GDP_Per_Capita  Value Footnotes
# 4146  Luxembourg  2022   115541.774828              NaN
# 4147  Luxembourg  2021   115683.493708              NaN
# 4148  Luxembourg  2020   111751.314751              NaN
# 4149  Luxembourg  2019   114542.496934              NaN
# 4150  Luxembourg  2018   114164.468558              NaN
# 4151  Luxembourg  2017   114985.842236              NaN
# 4152  Luxembourg  2016   116283.699681              NaN
# 4153  Luxembourg  2015   113182.728563              NaN
# 4154  Luxembourg  2014   113313.578898              NaN
# 4155  Luxembourg  2013   113050.663254              NaN
# 4156  Luxembourg  2012   112137.135491              NaN
# 4157  Luxembourg  2011   112998.390477              NaN
# 4158  Luxembourg  2010   114343.988089              NaN
# 4159  Luxembourg  2009   112230.081410              NaN
# 4160  Luxembourg  2008   118154.667184              NaN
# 4161  Luxembourg  2007   120647.822959              NaN
# ...

# %%
top_country.plot(x='Year',
                y='GDP_Per_Capita',
                kind='line')
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# 13##Which country had the lowest GDP per capita in 2020? Create a plot showing how this country's GDP per capita has changed over the timespan of the dataset. Bonus question: Is it true in general that coutries had a higher GDP per capita in 2020 than in 1990? Which countries had lower GDP per capita in 2020 than in 1990?You can use inlargest and inleast
#
# Answer Burundi	2020	711.355263. Yes.

# %% [markdown]
# gdp_dff[gdp_dff['Year']==2020].nsmallest(10, 'GDP_Per_Capita')<gdp_dff[gdp_dff['Year']==1990].nsmallest(10, 'GDP_Per_Capita')

# %%
gdp_dff[gdp_dff['Year']==1990].nsmallest(10, 'GDP_Per_Capita')
# Out:
#                 Country  Year  GDP_Per_Capita  Value Footnotes
# 4854         Mozambique  1990      460.123697              NaN
# 4887            Myanmar  1990      581.613311              NaN
# 2127           Ethiopia  1990      767.170419              NaN
# 7236             Uganda  1990      901.660809              NaN
# 5865             Rwanda  1990      933.013443              NaN
# 2033  Equatorial Guinea  1990      936.419751              NaN
# 4277             Malawi  1990      936.986300              NaN
# 970        Burkina Faso  1990      981.844762              NaN
# 1313               Chad  1990     1027.244423              NaN
# 5104              Niger  1990     1077.911465              NaN

# %%
bottom_country = gdp_dff[gdp_dff['Country']=='Burundi']

# %%
bottom_country
# Out:
#       Country  Year  GDP_Per_Capita  Value Footnotes
# 971   Burundi  2022      708.178317              NaN
# 972   Burundi  2021      714.066712              NaN
# 973   Burundi  2020      711.355263              NaN
# 974   Burundi  2019      729.658463              NaN
# 975   Burundi  2018      740.448223              NaN
# 976   Burundi  2017      750.787616              NaN
# 977   Burundi  2016      764.336602              NaN
# 978   Burundi  2015      781.579287              NaN
# 979   Burundi  2014      831.294839              NaN
# 980   Burundi  2013      824.610523              NaN
# 981   Burundi  2012      814.320771              NaN
# 982   Burundi  2011      807.664958              NaN
# 983   Burundi  2010      804.354941              NaN
# 984   Burundi  2009      801.803427              NaN
# 985   Burundi  2008      812.592170              NaN
# 986   Burundi  2007      807.447481              NaN
# 987   Burundi  2006      809.696011              NaN
# ...

# %%
bottom_country.plot(x='Year',
                y='GDP_Per_Capita',
                kind='line')
# Out:
# <Axes: xlabel='Year'>

# %%
gdp_dff[gdp_dff['Year']==2020].nlargest(1, 'GDP_Per_Capita')
# Out:
#          Country  Year  GDP_Per_Capita  Value Footnotes
# 4148  Luxembourg  2020   111751.314751              NaN

# %%
gdp_dff[gdp_dff['Year']==1990].nlargest(1, 'GDP_Per_Capita')
# Out:
#                    Country  Year  GDP_Per_Capita  Value Footnotes
# 7302  United Arab Emirates  1990   105893.626059              NaN

# %% [markdown]
# ##14 Read in the internet use dataset into a DataFrame named internet_df. You will likely get errors when doing this. Check the arguments for the read_csv function to find ones that can help correct the errors (https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) Once you are able to read it in, take per a look at the top and bottom few rows to make sure that it has been read in correctly. Also, check the datatypes of the columns.
#
# Answer

# %%
internet_df=pd.read_csv('../data/internet_use.csv', nrows=6083)

# %%
internet_df
# Out:
#      Country or Area  Year      Value Value Footnotes
# 0        Afghanistan  2019  17.600000               1
# 1        Afghanistan  2018  16.800000               2
# 2        Afghanistan  2017  13.500000               3
# 3        Afghanistan  2016  11.000000               4
# 4        Afghanistan  2015   8.260000               4
# ...              ...   ...        ...             ...
# 6078        Zimbabwe  1997   0.033080             NaN
# 6079        Zimbabwe  1996   0.016790             NaN
# 6080        Zimbabwe  1995   0.007684             NaN
# 6081        Zimbabwe  1994   0.001739             NaN
# 6082        Zimbabwe  1990   0.000000             NaN
#
# [6083 rows x 4 columns]

# %%
internet_df.dtypes
# Out:
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes     object
# dtype: object

# %% [markdown]
# 15##Drop the Value Footnotes column and rename the remaining three to 'Country', 'Year', and 'Internet_Users_Pct'.

# %%
internet_df
# Out:
#      Country or Area  Year      Value Value Footnotes
# 0        Afghanistan  2019  17.600000               1
# 1        Afghanistan  2018  16.800000               2
# 2        Afghanistan  2017  13.500000               3
# 3        Afghanistan  2016  11.000000               4
# 4        Afghanistan  2015   8.260000               4
# ...              ...   ...        ...             ...
# 6078        Zimbabwe  1997   0.033080             NaN
# 6079        Zimbabwe  1996   0.016790             NaN
# 6080        Zimbabwe  1995   0.007684             NaN
# 6081        Zimbabwe  1994   0.001739             NaN
# 6082        Zimbabwe  1990   0.000000             NaN
#
# [6083 rows x 4 columns]

# %%
internet_df=internet_df.drop(columns=['Value Footnotes'])

# %%
internet_dff=internet_df.rename(columns={"Country or Area": "Country",
                            "Value": "Internet_Users_Pct"})

# %% [markdown]
# ##16 Look at the number of observations in this dataset per year. What do you notice?

# %%
internet_dff.count()
# Out:
# Country               6083
# Year                  6083
# Internet_Users_Pct    6083
# dtype: int64

# %%
internet_dff['Year'].value_counts().reset_index().sort_values('Year')
# Out:
#     Year  count
# 0   1990    226
# 32  1991     39
# 31  1992     50
# 30  1993     66
# 29  1994     92
# 28  1995    141
# 26  1996    177
# 21  1997    188
# 20  1998    195
# 14  1999    207
# 10  2000    210
# 7   2001    212
# 5   2002    214
# 13  2003    208
# 9   2004    210
# 8   2005    212
# 6   2006    212
# 1   2007    217
# 3   2008    214
# 4   2009    214
# 11  2010    209
# 2   2011    214
# 12  2012    209
# 19  2013    203
# 17  2014    204
# 18  2015    203
# 15  2016    206
# 16  2017    205
# 27  2018    174
# 24  2019    185
# 23  2020    186
# 22  2021    186
# 25  2022    184
# 33  2023     11

# %%
internet_df
# Out:
#      Country or Area  Year      Value
# 0        Afghanistan  2019  17.600000
# 1        Afghanistan  2018  16.800000
# 2        Afghanistan  2017  13.500000
# 3        Afghanistan  2016  11.000000
# 4        Afghanistan  2015   8.260000
# ...              ...   ...        ...
# 6078        Zimbabwe  1997   0.033080
# 6079        Zimbabwe  1996   0.016790
# 6080        Zimbabwe  1995   0.007684
# 6081        Zimbabwe  1994   0.001739
# 6082        Zimbabwe  1990   0.000000
#
# [6083 rows x 3 columns]

# %% [markdown]
# 17## What is the first year to have a non-zero internet users percentage value?
#
# Answer 306	Australia	1990	0.585095

# %%
Years = internet_dff.groupby('Year')['Internet_Users_Pct'].count().sort_values().reset_index()

# %%
Years
# Out:
#     Year  Internet_Users_Pct
# 0   2023                  11
# 1   1991                  39
# 2   1992                  50
# 3   1993                  66
# 4   1994                  92
# 5   1995                 141
# 6   2018                 174
# 7   1996                 177
# 8   2022                 184
# 9   2019                 185
# 10  2021                 186
# 11  2020                 186
# 12  1997                 188
# 13  1998                 195
# 14  2013                 203
# 15  2015                 203
# 16  2014                 204
# 17  2017                 205
# 18  2016                 206
# 19  1999                 207
# 20  2003                 208
# 21  2010                 209
# 22  2012                 209
# 23  2004                 210
# 24  2000                 210
# 25  2006                 212
# 26  2005                 212
# 27  2001                 212
# 28  2009                 214
# 29  2008                 214
# 30  2002                 214
# ...

# %%
Years[Years['Internet_Users_Pct']<1]
# Out:
# Empty DataFrame
# Columns: [Year, Internet_Users_Pct]
# Index: []

# %%
internet_dff[internet_dff['Internet_Users_Pct']>0].nsmallest(1,"Year")
# Out:
#        Country  Year  Internet_Users_Pct
# 306  Australia  1990            0.585095

# %% [markdown]
# 18###How does the distribution of internet users percent differ for 2000 and 2014?
#
# Answer it is significantly higher in 2014

# %%
distribution=internet_dff[internet_dff['Year'].isin([2000, 2014])]

# %%
distribution
# Out:
#           Country  Year  Internet_Users_Pct
# 5     Afghanistan  2014            7.000000
# 28        Albania  2014           54.300000
# 42        Albania  2000            0.114097
# 57        Algeria  2014           29.500000
# 71        Algeria  2000            0.491706
# ...           ...   ...                 ...
# 6017        Yemen  2000            0.082500
# 6031       Zambia  2014            6.500000
# 6045       Zambia  2000            0.191072
# 6061     Zimbabwe  2014           16.364700
# 6075     Zimbabwe  2000            0.401434
#
# [414 rows x 3 columns]

# %%
sns.boxplot(x=distribution["Year"], y=distribution["Internet_Users_Pct"])
# Out:
# <Axes: xlabel='Year', ylabel='Internet_Users_Pct'>

# %% [markdown]
# 19#### For how many countries was the percentage of internet users below 5% in 2014?

# %%
year_2014=internet_dff[internet_dff["Year"]==2014]

# %%
year_2014
# Out:
#                   Country  Year  Internet_Users_Pct
# 5             Afghanistan  2014              7.0000
# 28                Albania  2014             54.3000
# 57                Algeria  2014             29.5000
# 87                Andorra  2014             86.1000
# 114                Angola  2014             21.3623
# ...                   ...   ...                 ...
# 5937             Viet Nam  2014             41.0000
# 5960  Virgin Islands (US)  2014             50.0700
# 6003                Yemen  2014             22.5500
# 6031               Zambia  2014              6.5000
# 6061             Zimbabwe  2014             16.3647
#
# [204 rows x 3 columns]

# %%
year_2014[year_2014["Internet_Users_Pct"]<5].count()
# Out:
# Country               10
# Year                  10
# Internet_Users_Pct    10
# dtype: int64

# %% [markdown]
# 20####Merge the two DataFrames to one. Do this in a way that keeps all rows from each of the two DataFrames. Call the new DataFrame gdp_and_internet_use. Look at the first and last few rows to confirm that it merged correctly.

# %% [markdown]
# ##Ryans way--   gdp_and_internet_use = gdp_df.merge(internet_df, how="outer",on=["Country","Year"])

# %%
gdp_and_internet_use=gdp_dff.merge(internet_dff, 'outer', on=["Country", "Year"])

# %%
gdp_and_internet_use=gdp_and_internet_use.drop(columns=['Value Footnotes'])

# %%
gdp_and_internet_use=gdp_and_internet_use.dropna(subset=["GDP_Per_Capita"])

# %%
gdp_and_internet_use
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2     Afghanistan  2002     1280.463171            0.004561
# 3     Afghanistan  2003     1292.333437            0.087891
# 4     Afghanistan  2004     1260.060581            0.105809
# 5     Afghanistan  2005     1352.320627            1.224150
# 6     Afghanistan  2006     1366.993146            2.107120
# ...           ...   ...             ...                 ...
# 9107     Zimbabwe  2018     2399.621551           25.000000
# 9108     Zimbabwe  2019     2203.396810           26.588300
# 9109     Zimbabwe  2020     1990.319419           29.298600
# 9110     Zimbabwe  2021     2115.144555           32.461600
# 9111     Zimbabwe  2022     2143.237574           32.561500
#
# [7662 rows x 4 columns]

# %% [markdown]
# 21## Find the three countries with the highest internet users percentage in 2014. Use a seaborn FacetGrid (https://seaborn.pydata.org/generated/seaborn.FacetGrid.html) to compare how the GDP per capita has changed over time for these three countries. What do you notice?

# %%
highest=gdp_and_internet_use[gdp_and_internet_use['Year']==2014].nlargest(3, "Internet_Users_Pct")

# %%
sns.FacetGrid(gdp_and_internet_use[gdp_and_internet_use["Country"].isin(highest["Country"])], col="Country").map(sns.scatterplot, "Year", "GDP_Per_Capita")

# %% [markdown]
# 22##Subset gdp_and_internet_use to just the year 2014. Save this as a new dataframe named gdp_and_internet_use_2014

# %%
gdp_and_internet_use_2014=gdp_and_internet_use[gdp_and_internet_use['Year']==2014]

# %%
gdp_and_internet_use_2014
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 14                    Afghanistan  2014     2144.449634              7.0000
# 46    Africa Eastern and Southern  2014     3642.875373                 NaN
# 79     Africa Western and Central  2014     4146.994622                 NaN
# 112                       Albania  2014    11586.817446             54.3000
# 145                       Algeria  2014    11561.259795             29.5000
# ...                           ...   ...             ...                 ...
# 8909                     Viet Nam  2014     7641.909252             41.0000
# 8978           West Bank and Gaza  2014     5967.073437                 NaN
# 9011                        World  2014    15120.730322                 NaN
# 9070                       Zambia  2014     3375.941270              6.5000
# 9103                     Zimbabwe  2014     2316.954536             16.3647
#
# [242 rows x 4 columns]

# %% [markdown]
# 23##Create a plot which compares Internet Users Percentage and GDP per Capita for the year 2014. What do you notice from this plot? If you see any unusual points, investigate them.

# %%
sns.barplot(x="Year", y="GDP_Per_Capita", data=gdp_and_internet_use_2014)
plt.show()

sns.barplot(x="Year", y="Internet_Users_Pct", data=gdp_and_internet_use_2014)
plt.show()

# %% [markdown]
# pd.gdp_and_internet_use_2014({'Internet_Users_Pct', 'GDP_Per_Capita': height,
#                    'Year': bars})

# %% [markdown]
# ###24) Stretch Question: Use the qcut function from pandas (https://pandas.pydata.org/docs/reference/api/pandas.qcut.html) to divide countries in gdp_per_capita_2014 into three groups based on their GDP per capita values. Label these groups as "Low", "Medium", and "High". Put these labels in a new column, named "GDP_group".

# %%
gdp_2014=gdp_and_internet_use[gdp_and_internet_use['Year']==2014]

# %%
gdp_group=gdp_2014['GDP_Per_Capita']

# %%
gdp_group
# Out:
# 14       2144.449634
# 46       3642.875373
# 79       4146.994622
# 112     11586.817446
# 145     11561.259795
#             ...
# 8909     7641.909252
# 8978     5967.073437
# 9011    15120.730322
# 9070     3375.941270
# 9103     2316.954536
# Name: GDP_Per_Capita, Length: 242, dtype: float64

# %%
gdp_per_capita_2014=gdp_dff[gdp_dff["Year"]==2014]

# %%
gdp_per_capita_2014
# Out:
#                           Country  Year  GDP_Per_Capita  Value Footnotes
# 7                     Afghanistan  2014     2144.449634              NaN
# 28    Africa Eastern and Southern  2014     3642.875373              NaN
# 61     Africa Western and Central  2014     4146.994622              NaN
# 94                        Albania  2014    11586.817446              NaN
# 127                       Algeria  2014    11561.259795              NaN
# ...                           ...   ...             ...              ...
# 7509                     Viet Nam  2014     7641.909252              NaN
# 7542           West Bank and Gaza  2014     5967.073437              NaN
# 7571                        World  2014    15120.730322              NaN
# 7604                       Zambia  2014     3375.941270              NaN
# 7637                     Zimbabwe  2014     2316.954536              NaN
#
# [242 rows x 4 columns]

# %%
qcut_column=pd.qcut(gdp_per_capita_2014["GDP_Per_Capita"], 3, labels=["Low", "Medium", "High"])

# %%
qcut_column
# Out:
# 7          Low
# 28         Low
# 61         Low
# 94      Medium
# 127     Medium
#          ...
# 7509    Medium
# 7542       Low
# 7571    Medium
# 7604       Low
# 7637       Low
# Name: GDP_Per_Capita, Length: 242, dtype: category
# Categories (3, object): ['Low' < 'Medium' < 'High']

# %%
gdp_per_capita_2014.insert(4, "GDP_group", qcut_column)

# %%
gdp_per_capita_2014=gdp_per_capita_2014.drop(columns=['Value Footnotes'])

# %%
gdp_per_capita_2014
# Out:
#                           Country  Year  GDP_Per_Capita GDP_group
# 7                     Afghanistan  2014     2144.449634       Low
# 28    Africa Eastern and Southern  2014     3642.875373       Low
# 61     Africa Western and Central  2014     4146.994622       Low
# 94                        Albania  2014    11586.817446    Medium
# 127                       Algeria  2014    11561.259795    Medium
# ...                           ...   ...             ...       ...
# 7509                     Viet Nam  2014     7641.909252    Medium
# 7542           West Bank and Gaza  2014     5967.073437       Low
# 7571                        World  2014    15120.730322    Medium
# 7604                       Zambia  2014     3375.941270       Low
# 7637                     Zimbabwe  2014     2316.954536       Low
#
# [242 rows x 4 columns]

# %% [markdown]
# 25##Stretch Question: How does the median internet users percentage compare for the three gdp groups?

# %% [markdown]
# plt.title('Boxplot of Values by Category')
# plt.suptitle('')  # Suppress the default title to avoid overlap
# plt.xlabel('Category')
# plt.ylabel('Value')
# plt.show()

# %%
sns.boxplot(by='gdp_per_capita_2014', column=['GDP_group'], grid=False)
# Out:
# <Axes: >
